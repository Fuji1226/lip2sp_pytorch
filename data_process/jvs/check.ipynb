# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_path = '/home/minami/dataset/jvs_ver1/gender_f0range.txt'
df = pd.read_csv(data_path)
df['data_split'] = ['train' for i in range(90)] + ['val' for i in range(10)]
df
# Out:
#    speaker Male_or_Female  minf0[Hz]  maxf0[Hz] data_split
# 0   jvs001              M         70        300      train
# 1   jvs002              F        130        390      train
# 2   jvs003              M         70        275      train
# 3   jvs004              F        130        430      train
# 4   jvs005              M         70        285      train
# ..     ...            ...        ...        ...        ...
# 95  jvs096              F        135        410        val
# 96  jvs097              M         70        305        val
# 97  jvs098              M         70        340        val
# 98  jvs099              M         70        300        val
# 99  jvs100              M         70        240        val
#
# [100 rows x 5 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
sns.scatterplot(df, x='minf0[Hz]', y='maxf0[Hz]', hue='Male_or_Female', ax=ax[0])
sns.scatterplot(df, x='minf0[Hz]', y='maxf0[Hz]', hue='data_split', ax=ax[1])
ax[0].grid()
ax[1].grid()
plt.show()
